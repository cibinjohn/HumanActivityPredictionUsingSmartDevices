# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data_df = pd.read_csv("data/combined_sensor_data_with_features.csv")
data_df.head()
# Out:
#              timestamp  Watch_battery  Watch_pressure  Watch_step_counter  \
# 0  2017-06-29 09:57:00            NaN             NaN                 NaN
# 1  2017-06-29 09:57:03            NaN             NaN                 NaN
# 2  2017-06-29 09:57:08           82.0             NaN                14.0
# 3  2017-06-29 09:57:09            NaN        964.2831                 NaN
# 4  2017-06-29 09:57:10            NaN             NaN                 NaN
#
#    Watch_step_detector  Watch_HEART_RATE_X  Watch_HEART_RATE_Y  Watch_ACC_X  \
# 0                  1.0                 NaN                 NaN          NaN
# 1                  NaN                79.0                 1.0          NaN
# 2                  1.0                 NaN                 NaN   -10.173126
# 3                  NaN                 NaN                 NaN          NaN
# 4                  NaN                76.0                 1.0          NaN
#
#    Watch_ACC_Y  Watch_ACC_Z  ...  Phone_AUDIO_W  Phone_AUDIO_X  Phone_AUDIO_Y  \
# 0          NaN          NaN  ...         8513.0      7546.2360        32767.0
# 1          NaN          NaN  ...        13602.0      7547.2380        32767.0
# 2    -1.471237     1.924393  ...         5198.0      7548.5195        32767.0
# 3          NaN          NaN  ...         4686.0      7548.1580        32767.0
# 4          NaN          NaN  ...         5239.0      7547.8667        32767.0
#
#    Phone_AUDIO_Z  Phone_ROTATION_VECTOR_A  Phone_ROTATION_VECTOR_B  \
# 0           45.0                      NaN                      NaN
# 1           45.0                      NaN                      NaN
# 2           45.0                      NaN                      NaN
# 3           45.0                      NaN                      NaN
# 4           45.0                      NaN                      NaN
#
#    Phone_ROTATION_VECTOR_C  Phone_ROTATION_VECTOR_D  Phone_ROTATION_VECTOR_E  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    activity
# 0       Eat
# 1       Eat
# 2       Eat
# 3       Eat
# 4       Eat
#
# [5 rows x 74 columns]

# %%
# Convert 'timestamp' column to datetime type
data_df['timestamp'] = pd.to_datetime(data_df['timestamp'])

# Set 'timestamp' as the index for easy manipulation
data_df.set_index('timestamp', inplace=True)

# %%
data_df.columns
# Out:
# Index(['Watch_battery', 'Watch_pressure', 'Watch_step_counter',
#        'Watch_step_detector', 'Watch_HEART_RATE_X', 'Watch_HEART_RATE_Y',
#        'Watch_ACC_X', 'Watch_ACC_Y', 'Watch_ACC_Z', 'Watch_GRAVITY_X',
#        'Watch_GRAVITY_Y', 'Watch_GRAVITY_Z', 'Watch_GYRO_X', 'Watch_GYRO_Y',
#        'Watch_GYRO_Z', 'Watch_LA_X', 'Watch_LA_Y', 'Watch_LA_Z', 'Watch_MAG_X',
#        'Watch_MAG_Y', 'Watch_MAG_Z', 'Watch_ORI_X', 'Watch_ORI_Y',
#        'Watch_ORI_Z', 'Watch_ROTATION_VECTOR_A', 'Watch_ROTATION_VECTOR_B',
#        'Watch_ROTATION_VECTOR_C', 'Watch_ROTATION_VECTOR_D',
#        'Watch_ROTATION_VECTOR_E', 'Glass_ACC_X', 'Glass_ACC_Y', 'Glass_ACC_Z',
#        'Glass_GYRO_X', 'Glass_GYRO_Y', 'Glass_GYRO_Z', 'Glass_EOG_L',
#        'Glass_EOG_R', 'Glass_EOG_H', 'Glass_EOG_V', 'Phone_battery',
#        'Phone_light', 'Phone_pressure', 'Phone_proximity',
#        'Phone_step_counter', 'Phone_step_detector', 'Phone_ACC_X',
#        'Phone_ACC_Y', 'Phone_ACC_Z', 'Phone_GRAVITY_X', 'Phone_GRAVITY_Y',
#        'Phone_GRAVITY_Z', 'Phone_GYRO_X', 'Phone_GYRO_Y', 'Phone_GYRO_Z',
#        'Phone_LA_X', 'Phone_LA_Y', 'Phone_LA_Z', 'Phone_MAG_X', 'Phone_MAG_Y',
#        'Phone_MAG_Z', 'Phone_ORI_X', 'Phone_ORI_Y', 'Phone_ORI_Z',
#        'Phone_AUDIO_W', 'Phone_AUDIO_X', 'Phone_AUDIO_Y', 'Phone_AUDIO_Z',
#        'Phone_ROTATION_VECTOR_A', 'Phone_ROTATION_VECTOR_B',
#        'Phone_ROTATION_VECTOR_C', 'Phone_ROTATION_VECTOR_D',
#        'Phone_ROTATION_VECTOR_E', 'activity'],
#       dtype='object')

# %%
pd.DataFrame(data_df.isna().sum())
# Out:
#                               0
# Watch_battery            284301
# Watch_pressure           283161
# Watch_step_counter       289648
# Watch_step_detector      287108
# Watch_HEART_RATE_X       266388
# ...                         ...
# Phone_ROTATION_VECTOR_B  241105
# Phone_ROTATION_VECTOR_C  241105
# Phone_ROTATION_VECTOR_D  241105
# Phone_ROTATION_VECTOR_E  241105
# activity                      0
#
# [73 rows x 1 columns]

# %%
features = ['Watch_battery', 'Watch_pressure', 'Watch_step_counter',
       'Watch_step_detector', 'Watch_HEART_RATE_X', 'Watch_HEART_RATE_Y',
       'Watch_ACC_X', 'Watch_ACC_Y', 'Watch_ACC_Z', 'Watch_GRAVITY_X',
       'Watch_GRAVITY_Y', 'Watch_GRAVITY_Z', 'Watch_GYRO_X', 'Watch_GYRO_Y',
       'Watch_GYRO_Z', 'Watch_LA_X', 'Watch_LA_Y', 'Watch_LA_Z', 'Watch_MAG_X',
       'Watch_MAG_Y', 'Watch_MAG_Z', 'Watch_ORI_X', 'Watch_ORI_Y',
       'Watch_ORI_Z', 'Watch_ROTATION_VECTOR_A', 'Watch_ROTATION_VECTOR_B',
       'Watch_ROTATION_VECTOR_C', 'Watch_ROTATION_VECTOR_D',
       'Watch_ROTATION_VECTOR_E', 'Glass_ACC_X', 'Glass_ACC_Y', 'Glass_ACC_Z',
       'Glass_GYRO_X', 'Glass_GYRO_Y', 'Glass_GYRO_Z', 'Glass_EOG_L',
       'Glass_EOG_R', 'Glass_EOG_H', 'Glass_EOG_V', 'Phone_battery',
       'Phone_light', 'Phone_pressure', 'Phone_proximity',
       'Phone_step_counter', 'Phone_step_detector', 'Phone_ACC_X',
       'Phone_ACC_Y', 'Phone_ACC_Z', 'Phone_GRAVITY_X', 'Phone_GRAVITY_Y',
       'Phone_GRAVITY_Z', 'Phone_GYRO_X', 'Phone_GYRO_Y', 'Phone_GYRO_Z',
       'Phone_LA_X', 'Phone_LA_Y', 'Phone_LA_Z', 'Phone_MAG_X', 'Phone_MAG_Y',
       'Phone_MAG_Z', 'Phone_ORI_X', 'Phone_ORI_Y', 'Phone_ORI_Z',
       'Phone_AUDIO_W', 'Phone_AUDIO_X', 'Phone_AUDIO_Y', 'Phone_AUDIO_Z',
       'Phone_ROTATION_VECTOR_A', 'Phone_ROTATION_VECTOR_B',
       'Phone_ROTATION_VECTOR_C', 'Phone_ROTATION_VECTOR_D',
       'Phone_ROTATION_VECTOR_E']

# %%
for feature in features:
    # Forward fill missing values for the next 60 seconds
    data_df[feature] = data_df[feature].fillna(method='ffill', limit=60)
    
    data_df[feature] = data_df[feature].fillna(method='bfill', limit=60)

# %%
# Find missing values

# %%
missing_values = data_df.isna().mean()*100
missing_values
# Out:
# Watch_battery              87.815149
# Watch_pressure             87.967219
# Watch_step_counter         92.933571
# Watch_step_detector        92.041795
# Watch_HEART_RATE_X         87.815837
#                              ...
# Phone_ROTATION_VECTOR_B    13.814612
# Phone_ROTATION_VECTOR_C    13.814612
# Phone_ROTATION_VECTOR_D    13.814612
# Phone_ROTATION_VECTOR_E    13.814612
# activity                    0.000000
# Length: 73, dtype: float64

# %%
missing_values[missing_values>30]
# Out:
# Watch_battery              87.815149
# Watch_pressure             87.967219
# Watch_step_counter         92.933571
# Watch_step_detector        92.041795
# Watch_HEART_RATE_X         87.815837
# Watch_HEART_RATE_Y         87.815837
# Watch_ACC_X                87.967219
# Watch_ACC_Y                87.967219
# Watch_ACC_Z                87.967219
# Watch_GRAVITY_X            94.371697
# Watch_GRAVITY_Y            94.371697
# Watch_GRAVITY_Z            94.371697
# Watch_GYRO_X               87.967219
# Watch_GYRO_Y               87.967219
# Watch_GYRO_Z               87.967219
# Watch_LA_X                 94.371353
# Watch_LA_Y                 94.371353
# Watch_LA_Z                 94.371353
# Watch_MAG_X                87.967219
# Watch_MAG_Y                87.967219
# Watch_MAG_Z                87.967219
# Watch_ORI_X                87.967563
# Watch_ORI_Y                87.967563
# Watch_ORI_Z                87.967563
# Watch_ROTATION_VECTOR_A    94.371353
# Watch_ROTATION_VECTOR_B    94.371353
# Watch_ROTATION_VECTOR_C    94.371353
# Watch_ROTATION_VECTOR_D    94.371353
# Watch_ROTATION_VECTOR_E    94.371353
# Glass_ACC_X                81.680406
# Glass_ACC_Y                81.680406
# Glass_ACC_Z                81.680406
# Glass_GYRO_X               81.680406
# Glass_GYRO_Y               81.680406
# Glass_GYRO_Z               81.680406
# Glass_EOG_L                81.680406
# Glass_EOG_R                81.680406
# Glass_EOG_H                81.680406
# Glass_EOG_V                81.680406
# Phone_battery              36.540790
# Phone_light                75.939599
# Phone_proximity            98.613137
# Phone_step_counter         73.351316
# Phone_step_detector        50.892464
# dtype: float64

# %%
columns_to_drop = missing_values[missing_values>30].index.tolist()
columns_to_drop
# Out:
# ['Watch_battery',
#  'Watch_pressure',
#  'Watch_step_counter',
#  'Watch_step_detector',
#  'Watch_HEART_RATE_X',
#  'Watch_HEART_RATE_Y',
#  'Watch_ACC_X',
#  'Watch_ACC_Y',
#  'Watch_ACC_Z',
#  'Watch_GRAVITY_X',
#  'Watch_GRAVITY_Y',
#  'Watch_GRAVITY_Z',
#  'Watch_GYRO_X',
#  'Watch_GYRO_Y',
#  'Watch_GYRO_Z',
#  'Watch_LA_X',
#  'Watch_LA_Y',
#  'Watch_LA_Z',
#  'Watch_MAG_X',
#  'Watch_MAG_Y',
#  'Watch_MAG_Z',
#  'Watch_ORI_X',
#  'Watch_ORI_Y',
#  'Watch_ORI_Z',
#  'Watch_ROTATION_VECTOR_A',
#  'Watch_ROTATION_VECTOR_B',
#  'Watch_ROTATION_VECTOR_C',
#  'Watch_ROTATION_VECTOR_D',
#  'Watch_ROTATION_VECTOR_E',
#  'Glass_ACC_X',
#  'Glass_ACC_Y',
#  'Glass_ACC_Z',
#  'Glass_GYRO_X',
#  'Glass_GYRO_Y',
#  'Glass_GYRO_Z',
#  'Glass_EOG_L',
#  'Glass_EOG_R',
#  'Glass_EOG_H',
#  'Glass_EOG_V',
#  'Phone_battery',
#  'Phone_light',
#  'Phone_proximity',
#  'Phone_step_counter',
#  'Phone_step_detector']

# %%
data_df.drop(columns=columns_to_drop, inplace=True)

# %%
data_df.columns
# Out:
# Index(['Phone_pressure', 'Phone_ACC_X', 'Phone_ACC_Y', 'Phone_ACC_Z',
#        'Phone_GRAVITY_X', 'Phone_GRAVITY_Y', 'Phone_GRAVITY_Z', 'Phone_GYRO_X',
#        'Phone_GYRO_Y', 'Phone_GYRO_Z', 'Phone_LA_X', 'Phone_LA_Y',
#        'Phone_LA_Z', 'Phone_MAG_X', 'Phone_MAG_Y', 'Phone_MAG_Z',
#        'Phone_ORI_X', 'Phone_ORI_Y', 'Phone_ORI_Z', 'Phone_AUDIO_W',
#        'Phone_AUDIO_X', 'Phone_AUDIO_Y', 'Phone_AUDIO_Z',
#        'Phone_ROTATION_VECTOR_A', 'Phone_ROTATION_VECTOR_B',
#        'Phone_ROTATION_VECTOR_C', 'Phone_ROTATION_VECTOR_D',
#        'Phone_ROTATION_VECTOR_E', 'activity'],
#       dtype='object')

# %% [markdown]
# # Sensor data count wrt activities

# %%
activity_data_count = data_df.groupby('activity').count()
activity_data_count
# Out:
#                                                   Phone_pressure  Phone_ACC_X  \
# activity
# At home                                                    56604        56588
# At home/Eat                                                    0            0
# Cooking                                                     7264         7264
# Eat                                                         8709         8709
# Eat/At home                                                 1863         1863
# Eat/In computer                                              901          901
# Eat/Phone was out of the pocket (forgot)/At home            1201         1201
# Football                                                      60           55
# In bus                                                     13670        13673
# In computer                                                20417        20418
# In computer/At home                                         6500         6507
# In computer/Eat                                               58           56
# In computer/Work                                            9722         9722
# In vehicle                                                  9307         9307
# Meeting                                                     8223         8223
# Movie                                                       6422         6422
# On bus stop                                                   61           61
# On bus stop/Walk                                            1021         1021
# Pause                                                      12382        12382
# Phone was out of the pocket (forgot)/At home                2942         2942
# Picnic                                                     18601        18601
# Running                                                       11           11
# Shop                                                        1562         1562
# Shop/Walk                                                   1202         1202
# Shopping& wearing                                           6181         6181
# Sleep                                                       6305         6307
# Took off glasses/Shop/Walk                                   481          481
# Train                                                       8519         8516
# Video games                                                 1374         1379
# Video games/At home                                         7141         7143
# Walk                                                       19378        19378
# Walking&party                                               8273         8273
# Watching TV/At home                                           52           58
# Work                                                        4083         4083
#
#                                                   Phone_ACC_Y  Phone_ACC_Z  \
# activity
# At home                                                 56588        56588
# At home/Eat                                                 0            0
# Cooking                                                  7264         7264
# Eat                                                      8709         8709
# Eat/At home                                              1863         1863
# Eat/In computer                                           901          901
# Eat/Phone was out of the pocket (forgot)/At home         1201         1201
# Football                                                   55           55
# In bus                                                  13673        13673
# In computer                                             20418        20418
# In computer/At home                                      6507         6507
# In computer/Eat                                            56           56
# In computer/Work                                         9722         9722
# In vehicle                                               9307         9307
# Meeting                                                  8223         8223
# Movie                                                    6422         6422
# On bus stop                                                61           61
# On bus stop/Walk                                         1021         1021
# Pause                                                   12382        12382
# Phone was out of the pocket (forgot)/At home             2942         2942
# Picnic                                                  18601        18601
# Running                                                    11           11
# Shop                                                     1562         1562
# Shop/Walk                                                1202         1202
# Shopping& wearing                                        6181         6181
# Sleep                                                    6307         6307
# Took off glasses/Shop/Walk                                481          481
# Train                                                    8516         8516
# Video games                                              1379         1379
# Video games/At home                                      7143         7143
# Walk                                                    19378        19378
# Walking&party                                            8273         8273
# Watching TV/At home                                        58           58
# Work                                                     4083         4083
#
#                                                   Phone_GRAVITY_X  \
# activity
# At home                                                     56616
# At home/Eat                                                     0
# Cooking                                                      7264
# Eat                                                          8709
# Eat/At home                                                  1863
# Eat/In computer                                               901
# Eat/Phone was out of the pocket (forgot)/At home             1201
# Football                                                       59
# In bus                                                      13673
# In computer                                                 20425
# In computer/At home                                          6499
# In computer/Eat                                                59
# In computer/Work                                             9722
# In vehicle                                                   9307
# Meeting                                                      8223
# Movie                                                        6422
# On bus stop                                                    61
# On bus stop/Walk                                             1021
# Pause                                                       12382
# Phone was out of the pocket (forgot)/At home                 2942
# Picnic                                                      18601
# Running                                                        11
# Shop                                                         1562
# Shop/Walk                                                    1202
# Shopping& wearing                                            6181
# Sleep                                                        6305
# Took off glasses/Shop/Walk                                    481
# Train                                                        8516
# Video games                                                  1379
# Video games/At home                                          7141
# Walk                                                        19378
# Walking&party                                                8271
# Watching TV/At home                                            59
# Work                                                         4083
#
#                                                   Phone_GRAVITY_Y  \
# activity
# At home                                                     56616
# At home/Eat                                                     0
# Cooking                                                      7264
# Eat                                                          8709
# Eat/At home                                                  1863
# Eat/In computer                                               901
# Eat/Phone was out of the pocket (forgot)/At home             1201
# Football                                                       59
# In bus                                                      13673
# In computer                                                 20425
# In computer/At home                                          6499
# In computer/Eat                                                59
# In computer/Work                                             9722
# In vehicle                                                   9307
# Meeting                                                      8223
# Movie                                                        6422
# On bus stop                                                    61
# On bus stop/Walk                                             1021
# Pause                                                       12382
# Phone was out of the pocket (forgot)/At home                 2942
# Picnic                                                      18601
# Running                                                        11
# Shop                                                         1562
# Shop/Walk                                                    1202
# Shopping& wearing                                            6181
# Sleep                                                        6305
# Took off glasses/Shop/Walk                                    481
# Train                                                        8516
# Video games                                                  1379
# Video games/At home                                          7141
# Walk                                                        19378
# Walking&party                                                8271
# Watching TV/At home                                            59
# Work                                                         4083
#
#                                                   Phone_GRAVITY_Z  \
# activity
# At home                                                     56616
# At home/Eat                                                     0
# Cooking                                                      7264
# Eat                                                          8709
# Eat/At home                                                  1863
# Eat/In computer                                               901
# Eat/Phone was out of the pocket (forgot)/At home             1201
# Football                                                       59
# In bus                                                      13673
# In computer                                                 20425
# In computer/At home                                          6499
# In computer/Eat                                                59
# In computer/Work                                             9722
# In vehicle                                                   9307
# Meeting                                                      8223
# Movie                                                        6422
# On bus stop                                                    61
# On bus stop/Walk                                             1021
# Pause                                                       12382
# Phone was out of the pocket (forgot)/At home                 2942
# Picnic                                                      18601
# Running                                                        11
# Shop                                                         1562
# Shop/Walk                                                    1202
# Shopping& wearing                                            6181
# Sleep                                                        6305
# Took off glasses/Shop/Walk                                    481
# Train                                                        8516
# Video games                                                  1379
# Video games/At home                                          7141
# Walk                                                        19378
# Walking&party                                                8271
# Watching TV/At home                                            59
# Work                                                         4083
#
#                                                   Phone_GYRO_X  Phone_GYRO_Y  \
# activity
# At home                                                  56598         56598
# At home/Eat                                                  0             0
# Cooking                                                   7264          7264
# Eat                                                       8709          8709
# Eat/At home                                               1863          1863
# Eat/In computer                                            901           901
# Eat/Phone was out of the pocket (forgot)/At home          1201          1201
# Football                                                    58            58
# In bus                                                   13673         13673
# In computer                                              20425         20425
# In computer/At home                                       6507          6507
# In computer/Eat                                             56            56
# In computer/Work                                          9722          9722
# In vehicle                                                9307          9307
# Meeting                                                   8223          8223
# Movie                                                     6422          6422
# On bus stop                                                 61            61
# On bus stop/Walk                                          1021          1021
# Pause                                                    12382         12382
# Phone was out of the pocket (forgot)/At home              2942          2942
# Picnic                                                   18601         18601
# Running                                                     11            11
# Shop                                                      1562          1562
# Shop/Walk                                                 1202          1202
# Shopping& wearing                                         6181          6181
# Sleep                                                     6307          6307
# Took off glasses/Shop/Walk                                 481           481
# Train                                                     8516          8516
# Video games                                               1379          1379
# Video games/At home                                       7143          7143
# Walk                                                     19378         19378
# Walking&party                                             8273          8273
# Watching TV/At home                                         58            58
# Work                                                      4083          4083
#
#                                                   Phone_GYRO_Z  ...  \
# activity                                                        ...
# At home                                                  56598  ...
# At home/Eat                                                  0  ...
# Cooking                                                   7264  ...
# Eat                                                       8709  ...
# Eat/At home                                               1863  ...
# Eat/In computer                                            901  ...
# Eat/Phone was out of the pocket (forgot)/At home          1201  ...
# Football                                                    58  ...
# In bus                                                   13673  ...
# In computer                                              20425  ...
# In computer/At home                                       6507  ...
# In computer/Eat                                             56  ...
# In computer/Work                                          9722  ...
# In vehicle                                                9307  ...
# Meeting                                                   8223  ...
# Movie                                                     6422  ...
# On bus stop                                                 61  ...
# On bus stop/Walk                                          1021  ...
# Pause                                                    12382  ...
# Phone was out of the pocket (forgot)/At home              2942  ...
# Picnic                                                   18601  ...
# Running                                                     11  ...
# Shop                                                      1562  ...
# Shop/Walk                                                 1202  ...
# Shopping& wearing                                         6181  ...
# Sleep                                                     6307  ...
# Took off glasses/Shop/Walk                                 481  ...
# Train                                                     8516  ...
# Video games                                               1379  ...
# Video games/At home                                       7143  ...
# Walk                                                     19378  ...
# Walking&party                                             8273  ...
# Watching TV/At home                                         58  ...
# Work                                                      4083  ...
#
#                                                   Phone_ORI_Z  Phone_AUDIO_W  \
# activity
# At home                                                 56609          56633
# At home/Eat                                                 0              0
# Cooking                                                  7264           7264
# Eat                                                      8709           8709
# Eat/At home                                              1863           1863
# Eat/In computer                                           901            901
# Eat/Phone was out of the pocket (forgot)/At home         1201           1201
# Football                                                   45             60
# In bus                                                  13663          13681
# In computer                                             20417          20426
# In computer/At home                                      6501           6516
# In computer/Eat                                            58             60
# In computer/Work                                         9722           9722
# In vehicle                                               9307           9307
# Meeting                                                  8223           8223
# Movie                                                    6422           6422
# On bus stop                                                61             61
# On bus stop/Walk                                         1021           1021
# Pause                                                   12382          12382
# Phone was out of the pocket (forgot)/At home             2942           2942
# Picnic                                                  18601          18601
# Running                                                    11             11
# Shop                                                     1562           1562
# Shop/Walk                                                1202           1202
# Shopping& wearing                                        6181           6181
# Sleep                                                    6307           6310
# Took off glasses/Shop/Walk                                481            481
# Train                                                    8523           8527
# Video games                                              1366           1381
# Video games/At home                                      7142           7144
# Walk                                                    19378          19378
# Walking&party                                            8273           8277
# Watching TV/At home                                        53             60
# Work                                                     4083           4083
#
#                                                   Phone_AUDIO_X  \
# activity
# At home                                                   56633
# At home/Eat                                                   0
# Cooking                                                    7264
# Eat                                                        8709
# Eat/At home                                                1863
# Eat/In computer                                             901
# Eat/Phone was out of the pocket (forgot)/At home           1201
# Football                                                     60
# In bus                                                    13681
# In computer                                               20426
# In computer/At home                                        6516
# In computer/Eat                                              60
# In computer/Work                                           9722
# In vehicle                                                 9307
# Meeting                                                    8223
# Movie                                                      6422
# On bus stop                                                  61
# On bus stop/Walk                                           1021
# Pause                                                     12382
# Phone was out of the pocket (forgot)/At home               2942
# Picnic                                                    18601
# Running                                                      11
# Shop                                                       1562
# Shop/Walk                                                  1202
# Shopping& wearing                                          6181
# Sleep                                                      6310
# Took off glasses/Shop/Walk                                  481
# Train                                                      8527
# Video games                                                1381
# Video games/At home                                        7144
# Walk                                                      19378
# Walking&party                                              8277
# Watching TV/At home                                          60
# Work                                                       4083
#
#                                                   Phone_AUDIO_Y  \
# activity
# At home                                                   56633
# At home/Eat                                                   0
# Cooking                                                    7264
# Eat                                                        8709
# Eat/At home                                                1863
# Eat/In computer                                             901
# Eat/Phone was out of the pocket (forgot)/At home           1201
# Football                                                     60
# In bus                                                    13681
# In computer                                               20426
# In computer/At home                                        6516
# In computer/Eat                                              60
# In computer/Work                                           9722
# In vehicle                                                 9307
# Meeting                                                    8223
# Movie                                                      6422
# On bus stop                                                  61
# On bus stop/Walk                                           1021
# Pause                                                     12382
# Phone was out of the pocket (forgot)/At home               2942
# Picnic                                                    18601
# Running                                                      11
# Shop                                                       1562
# Shop/Walk                                                  1202
# Shopping& wearing                                          6181
# Sleep                                                      6310
# Took off glasses/Shop/Walk                                  481
# Train                                                      8527
# Video games                                                1381
# Video games/At home                                        7144
# Walk                                                      19378
# Walking&party                                              8277
# Watching TV/At home                                          60
# Work                                                       4083
#
#                                                   Phone_AUDIO_Z  \
# activity
# At home                                                   56633
# At home/Eat                                                   0
# Cooking                                                    7264
# Eat                                                        8709
# Eat/At home                                                1863
# Eat/In computer                                             901
# Eat/Phone was out of the pocket (forgot)/At home           1201
# Football                                                     60
# In bus                                                    13681
# In computer                                               20426
# In computer/At home                                        6516
# In computer/Eat                                              60
# In computer/Work                                           9722
# In vehicle                                                 9307
# Meeting                                                    8223
# Movie                                                      6422
# On bus stop                                                  61
# On bus stop/Walk                                           1021
# Pause                                                     12382
# Phone was out of the pocket (forgot)/At home               2942
# Picnic                                                    18601
# Running                                                      11
# Shop                                                       1562
# Shop/Walk                                                  1202
# Shopping& wearing                                          6181
# Sleep                                                      6310
# Took off glasses/Shop/Walk                                  481
# Train                                                      8527
# Video games                                                1381
# Video games/At home                                        7144
# Walk                                                      19378
# Walking&party                                              8277
# Watching TV/At home                                          60
# Work                                                       4083
#
#                                                   Phone_ROTATION_VECTOR_A  \
# activity
# At home                                                             56610
# At home/Eat                                                             0
# Cooking                                                              7264
# Eat                                                                  8709
# Eat/At home                                                          1863
# Eat/In computer                                                       901
# Eat/Phone was out of the pocket (forgot)/At home                     1201
# Football                                                               50
# In bus                                                              13673
# In computer                                                         20426
# In computer/At home                                                  6498
# In computer/Eat                                                        56
# In computer/Work                                                     9722
# In vehicle                                                           9307
# Meeting                                                              8223
# Movie                                                                6422
# On bus stop                                                            61
# On bus stop/Walk                                                     1021
# Pause                                                               12382
# Phone was out of the pocket (forgot)/At home                         2942
# Picnic                                                              18601
# Running                                                                11
# Shop                                                                 1562
# Shop/Walk                                                            1202
# Shopping& wearing                                                    6181
# Sleep                                                                6305
# Took off glasses/Shop/Walk                                            481
# Train                                                                8521
# Video games                                                          1376
# Video games/At home                                                  7142
# Walk                                                                19378
# Walking&party                                                        8270
# Watching TV/At home                                                    59
# Work                                                                 4083
#
#                                                   Phone_ROTATION_VECTOR_B  \
# activity
# At home                                                             56610
# At home/Eat                                                             0
# Cooking                                                              7264
# Eat                                                                  8709
# Eat/At home                                                          1863
# Eat/In computer                                                       901
# Eat/Phone was out of the pocket (forgot)/At home                     1201
# Football                                                               50
# In bus                                                              13673
# In computer                                                         20426
# In computer/At home                                                  6498
# In computer/Eat                                                        56
# In computer/Work                                                     9722
# In vehicle                                                           9307
# Meeting                                                              8223
# Movie                                                                6422
# On bus stop                                                            61
# On bus stop/Walk                                                     1021
# Pause                                                               12382
# Phone was out of the pocket (forgot)/At home                         2942
# Picnic                                                              18601
# Running                                                                11
# Shop                                                                 1562
# Shop/Walk                                                            1202
# Shopping& wearing                                                    6181
# Sleep                                                                6305
# Took off glasses/Shop/Walk                                            481
# Train                                                                8521
# Video games                                                          1376
# Video games/At home                                                  7142
# Walk                                                                19378
# Walking&party                                                        8270
# Watching TV/At home                                                    59
# Work                                                                 4083
#
#                                                   Phone_ROTATION_VECTOR_C  \
# activity
# At home                                                             56610
# At home/Eat                                                             0
# Cooking                                                              7264
# Eat                                                                  8709
# Eat/At home                                                          1863
# Eat/In computer                                                       901
# Eat/Phone was out of the pocket (forgot)/At home                     1201
# Football                                                               50
# In bus                                                              13673
# In computer                                                         20426
# In computer/At home                                                  6498
# In computer/Eat                                                        56
# In computer/Work                                                     9722
# In vehicle                                                           9307
# Meeting                                                              8223
# Movie                                                                6422
# On bus stop                                                            61
# On bus stop/Walk                                                     1021
# Pause                                                               12382
# Phone was out of the pocket (forgot)/At home                         2942
# Picnic                                                              18601
# Running                                                                11
# Shop                                                                 1562
# Shop/Walk                                                            1202
# Shopping& wearing                                                    6181
# Sleep                                                                6305
# Took off glasses/Shop/Walk                                            481
# Train                                                                8521
# Video games                                                          1376
# Video games/At home                                                  7142
# Walk                                                                19378
# Walking&party                                                        8270
# Watching TV/At home                                                    59
# Work                                                                 4083
#
#                                                   Phone_ROTATION_VECTOR_D  \
# activity
# At home                                                             56610
# At home/Eat                                                             0
# Cooking                                                              7264
# Eat                                                                  8709
# Eat/At home                                                          1863
# Eat/In computer                                                       901
# Eat/Phone was out of the pocket (forgot)/At home                     1201
# Football                                                               50
# In bus                                                              13673
# In computer                                                         20426
# In computer/At home                                                  6498
# In computer/Eat                                                        56
# In computer/Work                                                     9722
# In vehicle                                                           9307
# Meeting                                                              8223
# Movie                                                                6422
# On bus stop                                                            61
# On bus stop/Walk                                                     1021
# Pause                                                               12382
# Phone was out of the pocket (forgot)/At home                         2942
# Picnic                                                              18601
# Running                                                                11
# Shop                                                                 1562
# Shop/Walk                                                            1202
# Shopping& wearing                                                    6181
# Sleep                                                                6305
# Took off glasses/Shop/Walk                                            481
# Train                                                                8521
# Video games                                                          1376
# Video games/At home                                                  7142
# Walk                                                                19378
# Walking&party                                                        8270
# Watching TV/At home                                                    59
# Work                                                                 4083
#
#                                                   Phone_ROTATION_VECTOR_E
# activity
# At home                                                             56610
# At home/Eat                                                             0
# Cooking                                                              7264
# Eat                                                                  8709
# Eat/At home                                                          1863
# Eat/In computer                                                       901
# Eat/Phone was out of the pocket (forgot)/At home                     1201
# Football                                                               50
# In bus                                                              13673
# In computer                                                         20426
# In computer/At home                                                  6498
# In computer/Eat                                                        56
# In computer/Work                                                     9722
# In vehicle                                                           9307
# Meeting                                                              8223
# Movie                                                                6422
# On bus stop                                                            61
# On bus stop/Walk                                                     1021
# Pause                                                               12382
# Phone was out of the pocket (forgot)/At home                         2942
# Picnic                                                              18601
# Running                                                                11
# Shop                                                                 1562
# Shop/Walk                                                            1202
# Shopping& wearing                                                    6181
# Sleep                                                                6305
# Took off glasses/Shop/Walk                                            481
# Train                                                                8521
# Video games                                                          1376
# Video games/At home                                                  7142
# Walk                                                                19378
# Walking&party                                                        8270
# Watching TV/At home                                                    59
# Work                                                                 4083
#
# [34 rows x 28 columns]

# %%
# saving it locally for analysis
activity_data_count.to_csv("Activity_vs_SensorDataCount.csv")

# %%
len(data_df.activity.value_counts())
# Out:
# 34

# %%
data_df.shape
# Out:
# (290656, 29)

# %%
labels_to_drop = ['At home/Eat','Football','Running','Watching TV/At home']

data_df["is_label_to_drop"] = data_df.activity.map(lambda x: x in labels_to_drop)
data_df = data_df[data_df.is_label_to_drop==False]

data_df.drop(columns=['is_label_to_drop'], inplace=True)

print(data_df.shape)
# Out:
# (288371, 29)

# %%
data_df.activity.value_counts()
# Out:
# At home                                             67202
# In computer                                         23791
# Walk                                                20703
# Picnic                                              18601
# In bus                                              15607
# Walking&party                                       14677
# Video games/At home                                 12523
# Pause                                               12382
# In computer/Work                                     9722
# Train                                                9576
# In vehicle                                           9549
# Sleep                                                9207
# Eat                                                  8709
# Meeting                                              8353
# Cooking                                              7264
# In computer/At home                                  6669
# Movie                                                6422
# Shopping& wearing                                    6181
# Work                                                 4083
# Video games                                          3782
# Phone was out of the pocket (forgot)/At home         2942
# In computer/Eat                                      2101
# Eat/At home                                          1896
# Shop                                                 1562
# Shop/Walk                                            1202
# Eat/Phone was out of the pocket (forgot)/At home     1201
# On bus stop/Walk                                     1021
# Eat/In computer                                       901
# Took off glasses/Shop/Walk                            481
# On bus stop                                            61
# Name: activity, dtype: int64

# %%
relabel_dict = {"On bus stop":"On bus stop/Walk",
               "Took off glasses/Shop/Walk":"Shop/Walk",
               "In computer/Eat":"In computer",
               "Eat/In computer":"In computer"}

# %%
data_df.activity = data_df.activity.map(lambda x: relabel_dict.get(x,x))

# %%
data_df.activity.value_counts()
# Out:
# At home                                             67202
# In computer                                         26793
# Walk                                                20703
# Picnic                                              18601
# In bus                                              15607
# Walking&party                                       14677
# Video games/At home                                 12523
# Pause                                               12382
# In computer/Work                                     9722
# Train                                                9576
# In vehicle                                           9549
# Sleep                                                9207
# Eat                                                  8709
# Meeting                                              8353
# Cooking                                              7264
# In computer/At home                                  6669
# Movie                                                6422
# Shopping& wearing                                    6181
# Work                                                 4083
# Video games                                          3782
# Phone was out of the pocket (forgot)/At home         2942
# Eat/At home                                          1896
# Shop/Walk                                            1683
# Shop                                                 1562
# Eat/Phone was out of the pocket (forgot)/At home     1201
# On bus stop/Walk                                     1082
# Name: activity, dtype: int64

# %%
data_df.isna().sum()
# Out:
# Phone_pressure             38004
# Phone_ACC_X                38005
# Phone_ACC_Y                38005
# Phone_ACC_Z                38005
# Phone_GRAVITY_X            37981
# Phone_GRAVITY_Y            37981
# Phone_GRAVITY_Z            37981
# Phone_GYRO_X               37988
# Phone_GYRO_Y               37988
# Phone_GYRO_Z               37988
# Phone_LA_X                 37981
# Phone_LA_Y                 37981
# Phone_LA_Z                 37981
# Phone_MAG_X                37969
# Phone_MAG_Y                37969
# Phone_MAG_Z                37969
# Phone_ORI_X                38006
# Phone_ORI_Y                38006
# Phone_ORI_Z                38006
# Phone_AUDIO_W              37910
# Phone_AUDIO_X              37910
# Phone_AUDIO_Y              37910
# Phone_AUDIO_Z              37910
# Phone_ROTATION_VECTOR_A    37988
# Phone_ROTATION_VECTOR_B    37988
# Phone_ROTATION_VECTOR_C    37988
# Phone_ROTATION_VECTOR_D    37988
# Phone_ROTATION_VECTOR_E    37988
# activity                       0
# dtype: int64

# %%
data_df.columns
# Out:
# Index(['Phone_pressure', 'Phone_ACC_X', 'Phone_ACC_Y', 'Phone_ACC_Z',
#        'Phone_GRAVITY_X', 'Phone_GRAVITY_Y', 'Phone_GRAVITY_Z', 'Phone_GYRO_X',
#        'Phone_GYRO_Y', 'Phone_GYRO_Z', 'Phone_LA_X', 'Phone_LA_Y',
#        'Phone_LA_Z', 'Phone_MAG_X', 'Phone_MAG_Y', 'Phone_MAG_Z',
#        'Phone_ORI_X', 'Phone_ORI_Y', 'Phone_ORI_Z', 'Phone_AUDIO_W',
#        'Phone_AUDIO_X', 'Phone_AUDIO_Y', 'Phone_AUDIO_Z',
#        'Phone_ROTATION_VECTOR_A', 'Phone_ROTATION_VECTOR_B',
#        'Phone_ROTATION_VECTOR_C', 'Phone_ROTATION_VECTOR_D',
#        'Phone_ROTATION_VECTOR_E', 'activity'],
#       dtype='object')

# %%
features = ['Phone_pressure', 'Phone_ACC_X', 'Phone_ACC_Y', 'Phone_ACC_Z',
       'Phone_GRAVITY_X', 'Phone_GRAVITY_Y', 'Phone_GRAVITY_Z', 'Phone_GYRO_X',
       'Phone_GYRO_Y', 'Phone_GYRO_Z', 'Phone_LA_X', 'Phone_LA_Y',
       'Phone_LA_Z', 'Phone_MAG_X', 'Phone_MAG_Y', 'Phone_MAG_Z',
       'Phone_ORI_X', 'Phone_ORI_Y', 'Phone_ORI_Z', 'Phone_AUDIO_W',
       'Phone_AUDIO_X', 'Phone_AUDIO_Y', 'Phone_AUDIO_Z',
       'Phone_ROTATION_VECTOR_A', 'Phone_ROTATION_VECTOR_B',
       'Phone_ROTATION_VECTOR_C', 'Phone_ROTATION_VECTOR_D',
       'Phone_ROTATION_VECTOR_E']

# %%
data_df.Phone_ACC_X.median()
# Out:
# 3.3817677

# %%
for feature in features:
    median = data_df[feature].median()
    data_df[feature].fillna(median, inplace=True)

# %%
data_df.isna().sum()
# Out:
# Phone_pressure             0
# Phone_ACC_X                0
# Phone_ACC_Y                0
# Phone_ACC_Z                0
# Phone_GRAVITY_X            0
# Phone_GRAVITY_Y            0
# Phone_GRAVITY_Z            0
# Phone_GYRO_X               0
# Phone_GYRO_Y               0
# Phone_GYRO_Z               0
# Phone_LA_X                 0
# Phone_LA_Y                 0
# Phone_LA_Z                 0
# Phone_MAG_X                0
# Phone_MAG_Y                0
# Phone_MAG_Z                0
# Phone_ORI_X                0
# Phone_ORI_Y                0
# Phone_ORI_Z                0
# Phone_AUDIO_W              0
# Phone_AUDIO_X              0
# Phone_AUDIO_Y              0
# Phone_AUDIO_Z              0
# Phone_ROTATION_VECTOR_A    0
# Phone_ROTATION_VECTOR_B    0
# Phone_ROTATION_VECTOR_C    0
# Phone_ROTATION_VECTOR_D    0
# Phone_ROTATION_VECTOR_E    0
# activity                   0
# dtype: int64

# %%
data_df.to_csv("data/P4_engineered_data.csv")
